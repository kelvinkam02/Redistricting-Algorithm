# %%
# !pip install geojson
# !pip install shapely
# !pip install PyShp
# !pip install networkx
# Out:
# Collecting geojson
#   Downloading geojson-3.1.0-py3-none-any.whl (15 kB)
# Installing collected packages: geojson
# Successfully installed geojson-3.1.0
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (2.0.2)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.10/dist-packages (from shapely) (1.23.5)
# Requirement already satisfied: PyShp in /usr/local/lib/python3.10/dist-packages (2.3.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.2.1)

# %%
import geojson
import pandas as pd
import numpy as np
import networkx as nx
import time
import csv
import ast
import shapefile as shp
from shapely.geometry import Polygon,shape,MultiPolygon
import shapely.ops
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %% [markdown]
# ### Helper functions

# %%
def isDistrictContiguous(district_num, assignment, contiguity_list, print_isolates=False, ignore_list=[]):
    ## input:
    ## district_num: the district number
    ## assignment: the assignment from precinct to district
    ## contiguity_list: the list of neighbors for each precinct, from the csv file
    contiguity_list.columns = ['Precinct','Neighbors']
    district_graph = nx.Graph() #creates an empty undirected graph
    district_nodes = assignment[assignment['District']==district_num]['GEOID20'].tolist()
    for i in ignore_list:
        try:
            district_nodes.remove(i)
        except ValueError:
            pass
    district_graph.add_nodes_from(district_nodes)
    for id in district_nodes:
        neighbors = ast.literal_eval(contiguity_list[contiguity_list['Precinct']==id]['Neighbors'].values.tolist()[0])
        # needed to convert string to list because the csv encodes the list as a string
        for neighbor in neighbors:
            if neighbor in district_nodes:
                district_graph.add_edge(id,neighbor)
    if(print_isolates):
        print(list(nx.isolates(district_graph)))
    return nx.is_connected(district_graph)

# %%
def getDistrictPopulations(assignment,data_file, num_district):
    population = {}
    for i in range (1,num_district+1):
        population[i] = data_file[data_file['GEOID20'].isin(assignment[assignment['District']==i]['GEOID20'])]['Total_2020_Total'].sum()
    return population

# %%
def getDistrictShape(district_id, assignment, boundaries):
    list_precincts = assignment[assignment['District']==district_id]['GEOID20']
    precinct_shapes = []
    for i in list_precincts:
        if shape(boundaries[i]).type == 'Polygon':
            precinct_shapes.append(Polygon(shape(boundaries[i])))
        elif shape(boundaries[i]).type == 'MultiPolygon':
            precinct_shapes.append(MultiPolygon(shape(boundaries[i])))
    district_shape = shapely.ops.unary_union(precinct_shapes)
    #print(district_shape)
    return district_shape

# %%
def pp_compactness(geom): # Polsby-Popper
    p = geom.length
    a = geom.area
    return (4*np.pi*a)/(p*p)

def box_reock_compactness(geom): # Reock on a rectangle bounding box
    a = geom.area
    bb = geom.bounds # bounds gives you the minimum bounding box (rectangle)
    bba = abs(bb[0]-bb[2])*abs(bb[1]-bb[3])
    return a/bba

# %% [markdown]
# # This Notebook will help you get started on NJ
# The data is in Canvas, you should upload it to your Google Drive first (if using Colab), or local filesystem (if using Jupyter).

# %% [markdown]
# ### This is the current assignment of precinct to congressional districts (12 of them for NJ)
# Note that the map shown in DRA is slightly different. This is because some precincts are split in the real assignment, and some additional precinct are created to handle special situations such as prisoners and overseas citizens. You can ignore this for the class project and just use the data and functions provided.

# %%
nj_current_assignment = pd.read_csv('/content/New Jersey Data/precinct-assignments-congress-nj.csv')
nj_current_assignment
# Out:
#           GEOID20  District
# 0     34033020001         2
# 1     34033001501         2
# 2     34033042009         2
# 3     34033000703         2
# 4     34033042001         2
# ...           ...       ...
# 6356  34039045302         7
# 6357  34039045303         7
# 6358  34039045404         7
# 6359  34039045801         7
# 6360  34039045802         7
#
# [6361 rows x 2 columns]

# %% [markdown]
# ### This is the current demographic and voter data
# The data has a lot of attributes that lists voters of different demographics and parties in different elections. You can look at the data Dictionary on Canvas to get details. For this recitation we will only keep votes from the 2020  presidential election and the total 2020 population counts. You can use additional columns (e.g., Governor's elections results, voting age (VAP) population counts, or the composite Dem/Rep score)

# %%
nj_precinct_data = pd.read_csv('/content/New Jersey Data/precinct-data-congress-nj.csv')
keepcolumns = ['GEOID20','District','Total_2020_Pres','Dem_2020_Pres','Rep_2020_Pres','Total_2020_Total','White_2020_Total','Hispanic_2020_Total','Black_2020_Total','Asian_2020_Total','Native_2020_Total','Pacific_2020_Total']
nj_precinct_data = nj_precinct_data[keepcolumns]
nj_precinct_data
# Out:
#           GEOID20  District  Total_2020_Pres  Dem_2020_Pres  Rep_2020_Pres  \
# 0     34001005101         2              876            393            472
# 1     34001005102         2              852            450            388
# 2     34001005103         2             1206            517            672
# 3     34001005201         2              828            348            469
# 4     34001005202         2              868            579            282
# ...           ...       ...              ...            ...            ...
# 6356  34041115002         7              606            182            418
# 6357  34041115003         7              617            187            418
# 6358  34041115004         7              478            160            308
# 6359  34041115005         7              592            201            381
# 6360  34041115006         7              464            138            319
#
#       Total_2020_Total  White_2020_Total  Hispanic_2020_Total  \
# 0                 1240               946                  128
# 1                 1913              1331                  211
# 2                 1760              1375                  177
# 3                 1311               906                  168
# 4                 1892               537                  336
# ...                ...               ...                  ...
# 6356               737               714                   11
# 6357               934               820                   60
# 6358               697               602                   66
# 6359               930               831                   47
# 6360               777               699                   30
#
#       Black_2020_Total  Asian_2020_Total  Native_2020_Total  \
# 0                  102                66                 24
# 1                  286                84                 38
# 2                   78               106                 20
# 3                  150                64                 50
# 4                  598               450                 25
# ...                ...               ...                ...
# 6356                 3                 8                  0
# 6357                26                10                 14
# 6358                16                 4                  5
# 6359                27                11                 12
# 6360                27                 9                 10
#
#       Pacific_2020_Total
# 0                      0
# 1                      4
# 2                      2
# 3                      5
# 4                      1
# ...                  ...
# 6356                   0
# 6357                   0
# 6358                   0
# 6359                   0
# 6360                   0
#
# [6361 rows x 12 columns]

# %% [markdown]
# ### This is the precinct boundary data (uses shapely)
#
# This is data that represents the geography of the districts. It is needed to test for contiguity, or for any districting partitioning method based on geography. The data is in Shapely format. Each district is represented as a set of points that are connected to create the district shape (in the long/lat coordinates). Shapely geometric functions can be used to compare the shapes. These can be quite inefficient to run, so I am also providing you a pre-computed index that, for each district, lists the districts that are contiguous to it. You can see the code to generate the index in Contiguity.ipynb.
#
# To manipulate the shapes, cast them into Shapely Polygons (see example below) and you can use the Polygon properties and functions: https://shapely.readthedocs.io/en/stable/reference/shapely.Polygon.html#shapely.Polygon

# %%
shpfile = '/content/New Jersey Data/nj_vtd_2020_bound.shp'
dbffile = '/content/New Jersey Data/nj_vtd_2020_bound.dbf'
shxfile = '/content/New Jersey Data/nj_vtd_2020_bound.shx'


shpfile = shp.Reader(shp=shpfile, shx=shxfile, dbf=dbffile)
nj_precinct_boundaries={}
for sr in shpfile.iterShapeRecords():
    geom = sr.shape # get geo bit
    rec = sr.record # get db fields
    nj_precinct_boundaries[rec[3]]=geom
# Out:
# ---------------------------------------------------------------------------
# ShapefileException                        Traceback (most recent call last)
# <ipython-input-9-19d8cdfd686a> in <cell line: 8>()
#       6 shpfile = shp.Reader(shp=shpfile, shx=shxfile, dbf=dbffile)
#       7 nj_precinct_boundaries={}
# ----> 8 for sr in shpfile.iterShapeRecords():
#       9     geom = sr.shape # get geo bit
#      10     rec = sr.record # get db fields
#
# /usr/local/lib/python3.10/dist-packages/shapefile.py in iterShapeRecords(self, fields, bbox)
#    1769         if bbox is None:
#    1770             # iterate through all shapes and records
# -> 1771             for shape, record in izip(self.iterShapes(), self.iterRecords(fields=fields)):
#    1772                 yield ShapeRecord(shape=shape, record=record)
#    1773         else:
#
# /usr/local/lib/python3.10/dist-packages/shapefile.py in iterShapes(self, bbox)
#    1468         arg as a list or tuple of xmin,ymin,xmax,ymax.
#    1469         """
# -> 1470         shp = self.__getFileObj(self.shp)
#    1471         # Found shapefiles which report incorrect
#    1472         # shp file length in the header. Can't trust
#
# /usr/local/lib/python3.10/dist-packages/shapefile.py in __getFileObj(self, f)
#    1261         available. If not a ShapefileException is raised."""
#    1262         if not f:
# -> 1263             raise ShapefileException("Shapefile Reader requires a shapefile or file-like object.")
#    1264         if self.shp and self.shpLength is None:
#    1265             self.load()
#
# ShapefileException: Shapefile Reader requires a shapefile or file-like object.

# %% [markdown]
# ### This is the precinct boundary data
#
# This use the contiguity index I have pre-computed using Contiguity.ipynb, that is stored in Contiguity_nj.csv.

# %%
nj_contiguity = pd.read_csv('/content/New Jersey Data/Contiguity_nj.csv', header=None)
nj_contiguity
# Out:
#                 0                                                  1
# 0     34033020001  ['34033001501', '34033060E01', '34033020002', ...
# 1     34033001501  ['34033020001', '34033042009', '34033060E01', ...
# 2     34033042009  ['34033001501', '34033030001', '34033004204', ...
# 3     34033000703  ['34033042001', '34033007001', '34033030001', ...
# 4     34033042001  ['34033000703', '34033007001', '34033030001', ...
# ...           ...                                                ...
# 6356  34039045302  ['34039045403', '34039045402', '34039045101', ...
# 6357  34039045303  ['34039045601', '34039045403', '34039045603', ...
# 6358  34039045404  ['34039045804', '34039045601', '34039045403', ...
# 6359  34039045801  ['34039020207', '34039045804', '34039020206', ...
# 6360  34039045802  ['34039045701', '34039020207', '34039045804', ...
#
# [6361 rows x 2 columns]

# %%
for i in range(1,13):
    print("District "+str(i)+" "+str(isDistrictContiguous(12, nj_current_assignment, nj_contiguity)))
# Out:
# District 1 True
# District 2 True
# District 3 True
# District 4 True
# District 5 True
# District 6 True
# District 7 True
# District 8 True
# District 9 True
# District 10 True
# District 11 True
# District 12 True

# %%
#Compactness of the current assignment
for district in range(1,13):
    print("D"+str(district)+" PP : "+str(pp_compactness(getDistrictShape(district,nj_current_assignment,nj_precinct_boundaries))))
    print("D"+str(district)+" BR : "+str(box_reock_compactness(getDistrictShape(district,nj_current_assignment,nj_precinct_boundaries))))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-bfc728ba11e3> in <cell line: 2>()
#       1 #Compactness of the current assignment
#       2 for district in range(1,13):
# ----> 3     print("D"+str(district)+" PP : "+str(pp_compactness(getDistrictShape(district,nj_current_assignment,nj_precinct_boundaries))))
#       4     print("D"+str(district)+" BR : "+str(box_reock_compactness(getDistrictShape(district,nj_current_assignment,nj_precinct_boundaries))))
#
# <ipython-input-5-4d60bb7804f1> in getDistrictShape(district_id, assignment, boundaries)
#       3     precinct_shapes = []
#       4     for i in list_precincts:
# ----> 5         if shape(boundaries[i]).type == 'Polygon':
#       6             precinct_shapes.append(Polygon(shape(boundaries[i])))
#       7         elif shape(boundaries[i]).type == 'MultiPolygon':
#
# KeyError: '34007170006'

# %%
# District Population of the current assignment
print(getDistrictPopulations(nj_current_assignment,nj_precinct_data, 12))
print(sum(getDistrictPopulations(nj_current_assignment,nj_precinct_data, 12)))
# Out:
# {1: 775340, 2: 778354, 3: 778489, 4: 767834, 5: 774454, 6: 778516, 7: 785173, 8: 800074, 9: 766863, 10: 746178, 11: 769523, 12: 768196}
# 78

# %% [markdown]
# # A simple geographical  redistricting strategy

# %% [markdown]
# We can create a simple geopgraphical map, like we did for NH. In this case, we have 12 districts, so let's splitting the district in half North/South, and in 6th  East/West.
# New Hampshire's bounding box is (-75.559614,38.928519,-73.893979,41.357423) (https://anthonylouisdagostino.com/bounding-boxes-for-all-us-states/)
# So let's start by splitting the state approximately though the middle longitude (-74.72) : everything west of longitude -71.583934 is in odd Districts, everything east is in even Districts. We will use the precinct centroids to assign them. Then we will divide each half per latitude on the ranges  (38.92, 39.3, 39.7, 40.1, 40.5,40.9,41.35)
# Import the Map to DRA to look at it.

# %%
nj_longlat_assignment = nj_current_assignment.copy()
nj_longlat_assignment['District'] = 0
for index, row in nj_longlat_assignment.iterrows():
    try:
        if shape(nj_precinct_boundaries[row['GEOID20']]).type == 'Polygon':
            centroid = Polygon(shape(nj_precinct_boundaries[row['GEOID20']])).centroid
        elif shape(nj_precinct_boundaries[row['GEOID20']]).type == 'MultiPolygon':
            centroid = MultiPolygon(shape(nj_precinct_boundaries[row['GEOID20']])).centroid
        else:
            print(shape(nj_precinct_boundaries[row['GEOID20']]).type)
            pass
        if centroid.x <= -74.72:
            if centroid.y <= 39.3:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 1
            elif centroid.y <= 39.7:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 3
            elif centroid.y <= 40.1:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 5
            elif centroid.y <= 40.5:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 7
            elif centroid.y <= 40.9:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 9
            else:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 11
        else:
            if centroid.y <= 39.3:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 2
            elif centroid.y <= 39.7:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 4
            elif centroid.y <= 40.1:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 6
            elif centroid.y <= 40.5:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 8
            elif centroid.y <= 40.9:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 10
            else:
                nj_longlat_assignment.iloc[index,nj_longlat_assignment.columns.get_loc('District')] = 12
    except KeyError:
        pass
#print(nh_longitude_assignment)
nj_longlat_assignment.to_csv('Recitation maps/nj_longlat_map.csv',index=False)
# Out:
# <ipython-input-117-97b5395461a6>:5: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   if shape(nj_precinct_boundaries[row['GEOID20']]).type == 'Polygon':
# <ipython-input-117-97b5395461a6>:7: ShapelyDeprecationWarning: The 'type' attribute is deprecated, and will be removed in the future. You can use the 'geom_type' attribute instead.
#   elif shape(nj_precinct_boundaries[row['GEOID20']]).type == 'MultiPolygon':

# %%
#Compactness of this Longlat assignment
for district in range(1,13):
    print("D"+str(district)+" PP : "+str(pp_compactness(getDistrictShape(district,nj_longlat_assignment,nj_precinct_boundaries))))
    print("D"+str(district)+" BR : "+str(box_reock_compactness(getDistrictShape(district,nj_longlat_assignment,nj_precinct_boundaries))))

# %%
# District Population of this longlat assignment
print(getDistrictPopulations(nj_longlat_assignment,nj_precinct_data, 12))

# %% [markdown]
# # Now create your own redistricting maps
# Remember to check for contiguity, and to ensure that the population of the districts are balanced (which is not the case in the example above.)

# %%
import pandas as pd
nj_unfair_assignment = nj_current_assignment.copy()


nj_contiguity.rename(columns={'Precinct': 'GEOID20', 1: 'neighbors'}, inplace=True)
precincts_add = 0


#UNFAIR MAP CODE
#choosing to make district 3 unfair because of current split between democrats and republicans
#this method will add precincts on the border of district 3 if they have a higher democratic population
#Precinct added:  2574 changed so that this map is at least 10 percent different than current map

#only flipped from neighors so that contiguity is never broken
while precincts_add < 2500:

    merged_df = pd.merge(nj_contiguity, nj_current_assignment, on='GEOID20')
    unfair_district = 3

    district_seven_precincts = merged_df[merged_df['District'] == unfair_district]

    district_seven_neighbors = district_seven_precincts['Neighbors'].tolist()
    nested_list_of_lists = [ast.literal_eval(geoid_str) for geoid_str in district_seven_neighbors]
    flat_district_seven_neighbors = [geoid for sublist in nested_list_of_lists for geoid in sublist]


    neighbors_df = pd.DataFrame(columns=['Neighbor', 'District'])

    for neighbor in flat_district_seven_neighbors:

      if neighbor in nj_current_assignment['GEOID20'].values:
          district = nj_current_assignment[nj_current_assignment['GEOID20'] == neighbor]['District'].values[0]
          neighbors_df = neighbors_df.append({'Neighbor': neighbor, 'District': district}, ignore_index=True)


    neighbors_not_in_district_seven = neighbors_df[neighbors_df['District'] != 3]
    neighbors_not_in_district_seven = neighbors_not_in_district_seven.rename(columns={'Neighbor': 'GEOID20'})



    merge = pd.merge(neighbors_not_in_district_seven, nj_precinct_data, on = "GEOID20")
    for index, row in merge.iterrows():
        precinct = row['GEOID20']
        democrats_total = row["Dem_2020_Pres"]
        republican_total = row["Rep_2020_Pres"]
        if democrats_total >= republican_total:
            old_district = nj_unfair_assignment.loc[nj_unfair_assignment["GEOID20"] == precinct, "District"]
            nj_unfair_assignment.loc[nj_unfair_assignment["GEOID20"] == precinct, "District"] = 3
            precincts_add += 1

#Precinct added:  2574

print("Precinct added: " , precincts_add)

filtered_rows = nj_precinct_data[(nj_precinct_data['District'] == 1) &
                                 ((nj_precinct_data['White_2020_Total'] == 771) |
                                  (nj_precinct_data['White_2020_Total'] == 619) |
                                  (nj_precinct_data['Black_2020_Total'] == 419))]
nj_unfair_assignment.loc[nj_unfair_assignment["GEOID20"] == 34005140006, "District"] = 3
nj_unfair_assignment.loc[nj_unfair_assignment["GEOID20"] == 34005140007, "District"] = 3
nj_unfair_assignment.loc[nj_unfair_assignment["GEOID20"] == 34005140008, "District"] = 3
precincts_to_reassign = ['34005140006', '34005140007', '34005140008']
nj_unfair_assignment.loc[nj_unfair_assignment['GEOID20'].isin(precincts_to_reassign), 'District'] = 3


columns_to_keep = ['GEOID20', 'District']
nj_unfair_assignment = nj_unfair_assignment[columns_to_keep]
nj_unfair_assignment.to_csv("maps/redistricting_unfair_assignment.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-cbc322d2f9d0> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 nj_unfair_assignment = nj_current_assignment.copy()
#       3
#       4
#       5 nj_contiguity.rename(columns={'Precinct': 'GEOID20', 1: 'neighbors'}, inplace=True)
#
# NameError: name 'nj_current_assignment' is not defined

# %%
import numpy as np
import pandas as pd
import ast
#flipstep:

#1. make 12 lists of each districts precincts
#2. make 12 lists of precinct neighbors of each district
#3. need to flip 650 precincts all of which have around the same population (between 200 and 500)
#4. for each district need to flip 100 precincts
#5. go through the neighbors of the precinct and randomly select 5 and flip to the current district
#this code accounts for neigbors in same district
nj_new_assignment = nj_current_assignment.copy()
nj_contiguity.rename(columns={'Precinct': 'GEOID20', 1: 'Neighbors'}, inplace=True)

merged_df = pd.merge(nj_contiguity, nj_current_assignment, on='GEOID20')

num_of_flips = 0
while num_of_flips < 650:
  for i in range(1, 13):
      print(f"Processing District {i}")

      district_precincts = merged_df[merged_df['District'] == i]
      district_neighbors = [ast.literal_eval(geoid_str) for geoid_str in district_precincts['Neighbors']]
      district_neighbors = [geoid for sublist in district_neighbors for geoid in sublist if len(nj_current_assignment.loc[nj_current_assignment['GEOID20'] == geoid, 'District'].values) > 0 and nj_current_assignment.loc[nj_current_assignment['GEOID20'] == geoid, 'District'].values[0] != i]

      print(len(district_neighbors))

      if len(district_neighbors) < 100:
          #print(f"Not enough neighbors for District {i}. Skipping.")
          continue

      flipped_precincts = np.random.choice(district_neighbors, 50)

      for flip in flipped_precincts:
          old_assignment_district = nj_current_assignment.loc[nj_current_assignment['GEOID20'] == flip, 'District'].values[0]
          print(f"Flipping {flip} from District {old_assignment_district} to District {i}")

          nj_new_assignment.loc[nj_new_assignment['GEOID20'] == flip, 'District'] = i
          num_of_flips += 1
          for j in range(1,13):
            if(isDistrictContiguous(j,nj_new_assignment,nj_contiguity) is False):
              nj_new_assignment.loc[nj_new_assignment['GEOID20']==flip,'District']= old_assignment_district
              num_of_flips -= 1
              break
          print(f"Total number of flips: {num_of_flips}")
          if num_of_flips > 650:
              break

print(f"Total number of flips: {num_of_flips}")

nj_new_assignment.to_csv("Recitation maps/new_jersey_fair.csv", index=False)
# Out:
# Processing District 1
# 117
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 0
# Flipping 34005040004 from District 3 to District 1
# Total number of flips: 1
# Flipping 34015005006 from District 2 to District 1
# Total number of flips: 2
# Flipping 34005125006 from District 3 to District 1
# Total number of flips: 3
# Flipping 34005040007 from District 3 to District 1
# Total number of flips: 4
# Flipping 34015020002 from District 2 to District 1
# Total number of flips: 5
# Flipping 34015025006 from District 2 to District 1
# Total number of flips: 6
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 6
# Flipping 34005065014 from District 3 to District 1
# Total number of flips: 7
# Flipping 34005040005 from District 3 to District 1
# Total number of flips: 8
# Flipping 34015025010 from District 2 to District 1
# Total number of flips: 9
# Flipping 34015005006 from District 2 to District 1
# Total number of flips: 10
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 10
# Flipping 34015025006 from District 2 to District 1
# Total number of flips: 11
# Flipping 34005125003 from District 3 to District 1
# Total number of flips: 12
# Flipping 34005040005 from District 3 to District 1
# Total number of flips: 13
# Flipping 34015040007 from District 2 to District 1
# Total number of flips: 14
# Flipping 34015025010 from District 2 to District 1
# Total number of flips: 15
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 15
# Flipping 34015040008 from District 2 to District 1
# Total number of flips: 16
# Flipping 34015040002 from District 2 to District 1
# Total number of flips: 17
# Flipping 34015040004 from District 2 to District 1
# Total number of flips: 18
# Flipping 34015040004 from District 2 to District 1
# Total number of flips: 19
# Flipping 34015040002 from District 2 to District 1
# Total number of flips: 20
# Flipping 34015015005 from District 2 to District 1
# Total number of flips: 21
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 21
# Flipping 34005040004 from District 3 to District 1
# Total number of flips: 22
# Flipping 34005105007 from District 3 to District 1
# Total number of flips: 23
# Flipping 34015040002 from District 2 to District 1
# Total number of flips: 24
# Flipping 34015040004 from District 2 to District 1
# Total number of flips: 25
# Flipping 34015035006 from District 2 to District 1
# Total number of flips: 26
# Flipping 34005160003 from District 3 to District 1
# Total number of flips: 27
# Flipping 34015020002 from District 2 to District 1
# Total number of flips: 28
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 28
# Flipping 34015020001 from District 2 to District 1
# Total number of flips: 29
# Flipping 34005105016 from District 3 to District 1
# Total number of flips: 30
# Flipping 34015040008 from District 2 to District 1
# Total number of flips: 31
# Flipping 34015035006 from District 2 to District 1
# Total number of flips: 32
# Flipping 34005040006 from District 3 to District 1
# Total number of flips: 33
# Flipping 34015015005 from District 2 to District 1
# Total number of flips: 34
# Flipping 34015025010 from District 2 to District 1
# Total number of flips: 35
# Flipping 34015025006 from District 2 to District 1
# Total number of flips: 36
# Flipping 34005065014 from District 3 to District 1
# Total number of flips: 37
# Flipping 34015040002 from District 2 to District 1
# Total number of flips: 38
# Flipping 34005040006 from District 3 to District 1
# Total number of flips: 39
# Flipping 34005160003 from District 3 to District 1
# Total number of flips: 40
# Flipping 34005065022 from District 3 to District 1
# Total number of flips: 41
# Flipping 34005065022 from District 3 to District 1
# Total number of flips: 42
# Flipping 34001065006 from District 2 to District 1
# Total number of flips: 43
# Flipping 34015035002 from District 2 to District 1
# Total number of flips: 44
# Processing District 2
# 129
# Flipping 34015050008 from District 1 to District 2
# Total number of flips: 44
# Flipping 34015055326 from District 1 to District 2
# Total number of flips: 44
# Flipping 34015070002 from District 1 to District 2
# Total number of flips: 45
# Flipping 34015050008 from District 1 to District 2
# Total number of flips: 45
# Flipping 34029030026 from District 4 to District 2
# Total number of flips: 46
# Flipping 34005185001 from District 3 to District 2
# Total number of flips: 47
# Flipping 34029060006 from District 4 to District 2
# Total number of flips: 48
# Flipping 34015030003 from District 1 to District 2
# Total number of flips: 49
# Flipping 34015030002 from District 1 to District 2
# Total number of flips: 50
# Flipping 34015015004 from District 1 to District 2
# Total number of flips: 51
# Flipping 34015070001 from District 1 to District 2
# Total number of flips: 52
# Flipping 34015015003 from District 1 to District 2
# Total number of flips: 53
# Flipping 34029060011 from District 4 to District 2
# Total number of flips: 54
# Flipping 34029060002 from District 4 to District 2
# Total number of flips: 55
# Flipping 34005005001 from District 3 to District 2
# Total number of flips: 56
# Flipping 34015015004 from District 1 to District 2
# Total number of flips: 57
# Flipping 34007180101 from District 1 to District 2
# Total number of flips: 57
# Flipping 34029060014 from District 4 to District 2
# Total number of flips: 58
# Flipping 34029060010 from District 4 to District 2
# Total number of flips: 58
# Flipping 34005185001 from District 3 to District 2
# Total number of flips: 59
# Flipping 34029060009 from District 4 to District 2
# Total number of flips: 60
# Flipping 34015030003 from District 1 to District 2
# Total number of flips: 61
# Flipping 34015055326 from District 1 to District 2
# Total number of flips: 61
# Flipping 34005165002 from District 3 to District 2
# Total number of flips: 62
# Flipping 34005185001 from District 3 to District 2
# Total number of flips: 63
# Flipping 34029025206 from District 4 to District 2
# Total number of flips: 64
# Flipping 34015015002 from District 1 to District 2
# Total number of flips: 64
# Flipping 34015015004 from District 1 to District 2
# Total number of flips: 65
# Flipping 34029025205 from District 4 to District 2
# Total number of flips: 66
# Flipping 34029060009 from District 4 to District 2
# Total number of flips: 67
# Flipping 34015030002 from District 1 to District 2
# Total number of flips: 68
# Flipping 34005005001 from District 3 to District 2
# Total number of flips: 69
# Flipping 34029060013 from District 4 to District 2
# Total number of flips: 70
# Flipping 34015050008 from District 1 to District 2
# Total number of flips: 71
# Flipping 34015030008 from District 1 to District 2
# Total number of flips: 71
# Flipping 34029060012 from District 4 to District 2
# Total number of flips: 71
# Flipping 34015030001 from District 1 to District 2
# Total number of flips: 71
# Flipping 34029025137 from District 4 to District 2
# Total number of flips: 72
# Flipping 34029135001 from District 4 to District 2
# Total number of flips: 73
# Flipping 34005185001 from District 3 to District 2
# Total number of flips: 74
# Flipping 34015055411 from District 1 to District 2
# Total number of flips: 75
# Flipping 34005005001 from District 3 to District 2
# Total number of flips: 76
# Flipping 34015055411 from District 1 to District 2
# Total number of flips: 77
# Flipping 34015055306 from District 1 to District 2
# Total number of flips: 77
# Flipping 34007180101 from District 1 to District 2
# Total number of flips: 77
# Flipping 34015070004 from District 1 to District 2
# Total number of flips: 78
# Flipping 34015055306 from District 1 to District 2
# Total number of flips: 78
# Flipping 34029060013 from District 4 to District 2
# Total number of flips: 79
# Flipping 34015055306 from District 1 to District 2
# Total number of flips: 79
# Flipping 34015050008 from District 1 to District 2
# Total number of flips: 80
# Processing District 3
# 264
# Flipping 34005140001 from District 1 to District 3
# Total number of flips: 81
# Flipping 34021055E08 from District 12 to District 3
# Total number of flips: 82
# Flipping 34025003009 from District 6 to District 3
# Total number of flips: 83
# Flipping 34001055002 from District 2 to District 3
# Total number of flips: 83
# Flipping 34025047007 from District 4 to District 3
# Total number of flips: 84
# Flipping 34021065013 from District 12 to District 3
# Total number of flips: 85
# Flipping 34025080003 from District 4 to District 3
# Total number of flips: 86
# Flipping 34025155044 from District 4 to District 3
# Total number of flips: 87
# Flipping 34007043017 from District 1 to District 3
# Total number of flips: 87
# Flipping 34021065015 from District 12 to District 3
# Total number of flips: 88
# Flipping 34021055E02 from District 12 to District 3
# Total number of flips: 89
# Flipping 34007043034 from District 1 to District 3
# Total number of flips: 90
# Flipping 34021030001 from District 12 to District 3
# Total number of flips: 91
# Flipping 34007030001 from District 1 to District 3
# Total number of flips: 92
# Flipping 34025095020 from District 4 to District 3
# Total number of flips: 93
# Flipping 34021055S03 from District 12 to District 3
# Total number of flips: 94
# Flipping 34007043045 from District 1 to District 3
# Total number of flips: 95
# Flipping 34023010002 from District 12 to District 3
# Total number of flips: 96
# Flipping 34029090040 from District 4 to District 3
# Total number of flips: 96
# Flipping 34025155031 from District 4 to District 3
# Total number of flips: 97
# Flipping 34001065004 from District 2 to District 3
# Total number of flips: 98
# Flipping 34023077510 from District 12 to District 3
# Total number of flips: 99
# Flipping 34021030005 from District 12 to District 3
# Total number of flips: 99
# Flipping 34029090040 from District 4 to District 3
# Total number of flips: 99
# Flipping 34025082013 from District 6 to District 3
# Total number of flips: 100
# Flipping 34021010007 from District 12 to District 3
# Total number of flips: 101
# Flipping 34025047005 from District 4 to District 3
# Total number of flips: 102
# Flipping 34023077208 from District 12 to District 3
# Total number of flips: 103
# Flipping 34021055E08 from District 12 to District 3
# Total number of flips: 104
# Flipping 34025082009 from District 6 to District 3
# Total number of flips: 105
# Flipping 34025082017 from District 6 to District 3
# Total number of flips: 106
# Flipping 34025155001 from District 4 to District 3
# Total number of flips: 107
# Flipping 34029115005 from District 4 to District 3
# Total number of flips: 108
# Flipping 34025082017 from District 6 to District 3
# Total number of flips: 109
# Flipping 34021065013 from District 12 to District 3
# Total number of flips: 110
# Flipping 34021055N01 from District 12 to District 3
# Total number of flips: 111
# Flipping 34029115002 from District 4 to District 3
# Total number of flips: 111
# Flipping 34001065003 from District 2 to District 3
# Total number of flips: 111
# Flipping 34025003012 from District 6 to District 3
# Total number of flips: 111
# Flipping 34023010003 from District 12 to District 3
# Total number of flips: 112
# Flipping 34029115001 from District 4 to District 3
# Total number of flips: 113
# Flipping 34021050003 from District 12 to District 3
# Total number of flips: 114
# Flipping 34025082009 from District 6 to District 3
# Total number of flips: 115
# Flipping 34025155001 from District 4 to District 3
# Total number of flips: 116
# Flipping 34021065013 from District 12 to District 3
# Total number of flips: 117
# Flipping 34005140001 from District 1 to District 3
# Total number of flips: 118
# Flipping 34007043045 from District 1 to District 3
# Total number of flips: 119
# Flipping 34023065117 from District 12 to District 3
# Total number of flips: 120
# Flipping 34025080003 from District 4 to District 3
# Total number of flips: 121
# Flipping 34023065306 from District 12 to District 3
# Total number of flips: 122
# Processing District 4
# 223
# Flipping 34025210002 from District 6 to District 4
# Total number of flips: 123
# Flipping 34005130001 from District 3 to District 4
# Total number of flips: 124
# Flipping 34029003005 from District 2 to District 4
# Total number of flips: 125
# Flipping 34025170016 from District 6 to District 4
# Total number of flips: 125
# Flipping 34025170013 from District 6 to District 4
# Total number of flips: 126
# Flipping 34029025139 from District 2 to District 4
# Total number of flips: 127
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 127
# Flipping 34025155006 from District 6 to District 4
# Total number of flips: 128
# Flipping 34025005001 from District 6 to District 4
# Total number of flips: 129
# Flipping 34025090010 from District 3 to District 4
# Total number of flips: 130
# Flipping 34025015009 from District 6 to District 4
# Total number of flips: 131
# Flipping 34029025139 from District 2 to District 4
# Total number of flips: 132
# Flipping 34025170020 from District 6 to District 4
# Total number of flips: 133
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 133
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 133
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 133
# Flipping 34025080023 from District 3 to District 4
# Total number of flips: 133
# Flipping 34025ZZZZZZ from District 6 to District 4
# Total number of flips: 133
# Flipping 34025015002 from District 6 to District 4
# Total number of flips: 134
# Flipping 34029025104 from District 2 to District 4
# Total number of flips: 135
# Flipping 34025190004 from District 6 to District 4
# Total number of flips: 136
# Flipping 34025170015 from District 6 to District 4
# Total number of flips: 137
# Flipping 34025ZZZZZZ from District 6 to District 4
# Total number of flips: 137
# Flipping 34025080024 from District 3 to District 4
# Total number of flips: 138
# Flipping 34025ZZZZZZ from District 6 to District 4
# Total number of flips: 138
# Flipping 34025265006 from District 6 to District 4
# Total number of flips: 139
# Flipping 34025ZZZZZZ from District 6 to District 4
# Total number of flips: 139
# Flipping 34025ZZZZZZ from District 6 to District 4
# Total number of flips: 139
# Flipping 34025170004 from District 6 to District 4
# Total number of flips: 140
# Flipping 34025255003 from District 3 to District 4
# Total number of flips: 141
# Flipping 34025172002 from District 6 to District 4
# Total number of flips: 142
# Flipping 34025082003 from District 6 to District 4
# Total number of flips: 143
# Flipping 34025155009 from District 6 to District 4
# Total number of flips: 144
# Flipping 34025080022 from District 3 to District 4
# Total number of flips: 145
# Flipping 34025ZZZZZZ from District 6 to District 4
# Total number of flips: 145
# Flipping 34025160007 from District 3 to District 4
# Total number of flips: 146
# Flipping 34025170013 from District 6 to District 4
# Total number of flips: 147
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 147
# Flipping 34025155006 from District 6 to District 4
# Total number of flips: 148
# Flipping 34025155004 from District 6 to District 4
# Total number of flips: 149
# Flipping 34025170016 from District 6 to District 4
# Total number of flips: 150
# Flipping 34029025134 from District 2 to District 4
# Total number of flips: 151
# Flipping 34025080018 from District 3 to District 4
# Total number of flips: 152
# Flipping 34029025134 from District 2 to District 4
# Total number of flips: 153
# Flipping 34029025000 from District 2 to District 4
# Total number of flips: 154
# Flipping 34025155003 from District 6 to District 4
# Total number of flips: 155
# Flipping 34025170020 from District 6 to District 4
# Total number of flips: 156
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 156
# Flipping 34025170016 from District 6 to District 4
# Total number of flips: 157
# Flipping 34029025134 from District 2 to District 4
# Total number of flips: 158
# Processing District 5
# 171
# Flipping 34003295001 from District 9 to District 5
# Total number of flips: 159
# Flipping 34037035003 from District 7 to District 5
# Total number of flips: 160
# Flipping 34037020004 from District 7 to District 5
# Total number of flips: 161
# Flipping 34003170007 from District 9 to District 5
# Total number of flips: 162
# Flipping 34037090012 from District 7 to District 5
# Total number of flips: 163
# Flipping 34037090008 from District 7 to District 5
# Total number of flips: 164
# Flipping 34037115001 from District 7 to District 5
# Total number of flips: 165
# Flipping 34031030003 from District 9 to District 5
# Total number of flips: 166
# Flipping 34003065003 from District 9 to District 5
# Total number of flips: 167
# Flipping 34037035003 from District 7 to District 5
# Total number of flips: 168
# Flipping 34031020201 from District 9 to District 5
# Total number of flips: 169
# Flipping 34027075003 from District 11 to District 5
# Total number of flips: 170
# Flipping 34003210001 from District 9 to District 5
# Total number of flips: 171
# Flipping 34003170006 from District 9 to District 5
# Total number of flips: 172
# Flipping 34027165001 from District 11 to District 5
# Total number of flips: 173
# Flipping 34037100002 from District 7 to District 5
# Total number of flips: 174
# Flipping 34037090012 from District 7 to District 5
# Total number of flips: 175
# Flipping 34003100001 from District 9 to District 5
# Total number of flips: 176
# Flipping 34003210008 from District 9 to District 5
# Total number of flips: 177
# Flipping 34031020202 from District 9 to District 5
# Total number of flips: 178
# Flipping 34031045002 from District 9 to District 5
# Total number of flips: 179
# Flipping 34003030015 from District 9 to District 5
# Total number of flips: 180
# Flipping 34003245004 from District 9 to District 5
# Total number of flips: 180
# Flipping 34003210007 from District 9 to District 5
# Total number of flips: 181
# Flipping 34027070013 from District 11 to District 5
# Total number of flips: 182
# Flipping 34031020304 from District 9 to District 5
# Total number of flips: 183
# Flipping 34027015004 from District 11 to District 5
# Total number of flips: 184
# Flipping 34037035004 from District 7 to District 5
# Total number of flips: 185
# Flipping 34003285011 from District 9 to District 5
# Total number of flips: 186
# Flipping 34031020402 from District 9 to District 5
# Total number of flips: 187
# Flipping 34031020201 from District 9 to District 5
# Total number of flips: 188
# Flipping 34027015004 from District 11 to District 5
# Total number of flips: 189
# Flipping 34027015004 from District 11 to District 5
# Total number of flips: 190
# Flipping 34003030010 from District 9 to District 5
# Total number of flips: 190
# Flipping 34003270002 from District 9 to District 5
# Total number of flips: 190
# Flipping 34003065003 from District 9 to District 5
# Total number of flips: 191
# Flipping 34003100002 from District 9 to District 5
# Total number of flips: 192
# Flipping 34003100001 from District 9 to District 5
# Total number of flips: 193
# Flipping 34003125009 from District 9 to District 5
# Total number of flips: 194
# Flipping 34027175603 from District 11 to District 5
# Total number of flips: 195
# Flipping 34031020203 from District 9 to District 5
# Total number of flips: 196
# Flipping 34003295001 from District 9 to District 5
# Total number of flips: 197
# Flipping 34003295001 from District 9 to District 5
# Total number of flips: 198
# Flipping 34031040311 from District 9 to District 5
# Total number of flips: 199
# Flipping 34037035004 from District 7 to District 5
# Total number of flips: 200
# Flipping 34003310001 from District 9 to District 5
# Total number of flips: 201
# Flipping 34037100001 from District 7 to District 5
# Total number of flips: 202
# Flipping 34003065003 from District 9 to District 5
# Total number of flips: 203
# Flipping 34003310001 from District 9 to District 5
# Total number of flips: 204
# Flipping 34031040309 from District 9 to District 5
# Total number of flips: 205
# Processing District 6
# 279
# Flipping 34025225002 from District 4 to District 6
# Total number of flips: 206
# Flipping 34025240003 from District 4 to District 6
# Total number of flips: 207
# Flipping 34025225003 from District 4 to District 6
# Total number of flips: 207
# Flipping 34023075014 from District 12 to District 6
# Total number of flips: 208
# Flipping 34023077409 from District 12 to District 6
# Total number of flips: 209
# Flipping 34025247010 from District 4 to District 6
# Total number of flips: 210
# Flipping 34025055007 from District 4 to District 6
# Total number of flips: 211
# Flipping 34023020013 from District 12 to District 6
# Total number of flips: 212
# Flipping 34025247006 from District 4 to District 6
# Total number of flips: 213
# Flipping 34025155033 from District 4 to District 6
# Total number of flips: 213
# Flipping 34023075006 from District 12 to District 6
# Total number of flips: 213
# Flipping 34035040544 from District 12 to District 6
# Total number of flips: 214
# Flipping 34023020002 from District 12 to District 6
# Total number of flips: 215
# Flipping 34025155008 from District 4 to District 6
# Total number of flips: 216
# Flipping 34023055010 from District 12 to District 6
# Total number of flips: 217
# Flipping 34039065405 from District 7 to District 6
# Total number of flips: 218
# Flipping 34025035004 from District 4 to District 6
# Total number of flips: 219
# Flipping 34025185003 from District 4 to District 6
# Total number of flips: 219
# Flipping 34025030002 from District 4 to District 6
# Total number of flips: 220
# Flipping 34025220001 from District 4 to District 6
# Total number of flips: 221
# Flipping 34025055007 from District 4 to District 6
# Total number of flips: 222
# Flipping 34025090010 from District 3 to District 6
# Total number of flips: 222
# Flipping 34025155021 from District 4 to District 6
# Total number of flips: 223
# Flipping 34039060306 from District 12 to District 6
# Total number of flips: 224
# Flipping 34035040523 from District 12 to District 6
# Total number of flips: 225
# Flipping 34023075014 from District 12 to District 6
# Total number of flips: 226
# Flipping 34025260015 from District 4 to District 6
# Total number of flips: 227
# Flipping 34025140026 from District 3 to District 6
# Total number of flips: 228
# Flipping 34025155010 from District 4 to District 6
# Total number of flips: 229
# Flipping 34035040548 from District 12 to District 6
# Total number of flips: 230
# Flipping 34025090002 from District 3 to District 6
# Total number of flips: 231
# Flipping 34025185001 from District 4 to District 6
# Total number of flips: 232
# Flipping 34023115010 from District 12 to District 6
# Total number of flips: 233
# Flipping 34039010101 from District 7 to District 6
# Total number of flips: 234
# Flipping 34039065302 from District 7 to District 6
# Total number of flips: 235
# Flipping 34039010404 from District 7 to District 6
# Total number of flips: 236
# Flipping 34039065401 from District 7 to District 6
# Total number of flips: 237
# Flipping 34023077206 from District 12 to District 6
# Total number of flips: 238
# Flipping 34025030001 from District 4 to District 6
# Total number of flips: 239
# Flipping 34025185011 from District 4 to District 6
# Total number of flips: 240
# Flipping 34039010104 from District 7 to District 6
# Total number of flips: 241
# Flipping 34039065304 from District 7 to District 6
# Total number of flips: 242
# Flipping 34039045701 from District 7 to District 6
# Total number of flips: 243
# Flipping 34025055008 from District 4 to District 6
# Total number of flips: 243
# Flipping 34023020005 from District 12 to District 6
# Total number of flips: 244
# Flipping 34023075003 from District 12 to District 6
# Total number of flips: 245
# Flipping 34039010101 from District 7 to District 6
# Total number of flips: 246
# Flipping 34025247006 from District 4 to District 6
# Total number of flips: 247
# Flipping 34039060404 from District 12 to District 6
# Total number of flips: 248
# Flipping 34025155010 from District 4 to District 6
# Total number of flips: 249
# Processing District 7
# 312
# Flipping 34037030001 from District 5 to District 7
# Total number of flips: 250
# Flipping 34035070006 from District 12 to District 7
# Total number of flips: 251
# Flipping 34027070004 from District 11 to District 7
# Total number of flips: 252
# Flipping 34027020001 from District 11 to District 7
# Total number of flips: 253
# Flipping 34039030002 from District 10 to District 7
# Total number of flips: 254
# Flipping 34035070004 from District 12 to District 7
# Total number of flips: 255
# Flipping 34027160012 from District 11 to District 7
# Total number of flips: 256
# Flipping 34039060108 from District 12 to District 7
# Total number of flips: 257
# Flipping 34027070001 from District 11 to District 7
# Total number of flips: 258
# Flipping 34037065001 from District 5 to District 7
# Total number of flips: 258
# Flipping 34027160015 from District 11 to District 7
# Total number of flips: 259
# Flipping 34023025001 from District 6 to District 7
# Total number of flips: 260
# Flipping 34023125501 from District 6 to District 7
# Total number of flips: 260
# Flipping 34035050028 from District 12 to District 7
# Total number of flips: 261
# Flipping 34027025010 from District 11 to District 7
# Total number of flips: 262
# Flipping 34021030003 from District 12 to District 7
# Total number of flips: 263
# Flipping 34023015001 from District 12 to District 7
# Total number of flips: 263
# Flipping 34027025008 from District 11 to District 7
# Total number of flips: 264
# Flipping 34035030003 from District 12 to District 7
# Total number of flips: 265
# Flipping 34013060001 from District 11 to District 7
# Total number of flips: 266
# Flipping 34023015006 from District 12 to District 7
# Total number of flips: 267
# Flipping 34027160017 from District 11 to District 7
# Total number of flips: 268
# Flipping 34021030012 from District 12 to District 7
# Total number of flips: 269
# Flipping 34039060205 from District 12 to District 7
# Total number of flips: 270
# Flipping 34027045101 from District 11 to District 7
# Total number of flips: 271
# Flipping 34023005011 from District 6 to District 7
# Total number of flips: 272
# Flipping 34037010003 from District 5 to District 7
# Total number of flips: 273
# Flipping 34039060209 from District 12 to District 7
# Total number of flips: 274
# Flipping 34035070005 from District 12 to District 7
# Total number of flips: 275
# Flipping 34013060009 from District 11 to District 7
# Total number of flips: 276
# Flipping 34039030001 from District 10 to District 7
# Total number of flips: 277
# Flipping 34039015014 from District 10 to District 7
# Total number of flips: 278
# Flipping 34027070001 from District 11 to District 7
# Total number of flips: 279
# Flipping 34035030003 from District 12 to District 7
# Total number of flips: 280
# Flipping 34037010006 from District 5 to District 7
# Total number of flips: 280
# Flipping 34035030003 from District 12 to District 7
# Total number of flips: 281
# Flipping 34027020008 from District 11 to District 7
# Total number of flips: 282
# Flipping 34035070004 from District 12 to District 7
# Total number of flips: 283
# Flipping 34027070008 from District 11 to District 7
# Total number of flips: 284
# Flipping 34039040001 from District 10 to District 7
# Total number of flips: 285
# Flipping 34027070002 from District 11 to District 7
# Total number of flips: 286
# Flipping 34035065007 from District 12 to District 7
# Total number of flips: 287
# Flipping 34035070006 from District 12 to District 7
# Total number of flips: 288
# Flipping 34037010003 from District 5 to District 7
# Total number of flips: 289
# Flipping 34037010003 from District 5 to District 7
# Total number of flips: 290
# Flipping 34037055003 from District 5 to District 7
# Total number of flips: 291
# Flipping 34027065003 from District 11 to District 7
# Total number of flips: 292
# Flipping 34027160013 from District 11 to District 7
# Total number of flips: 293
# Flipping 34023125507 from District 6 to District 7
# Total number of flips: 293
# Flipping 34037010003 from District 5 to District 7
# Total number of flips: 294
# Processing District 8
# 233
# Flipping 34039095017 from District 10 to District 8
# Total number of flips: 295
# Flipping 34017045205 from District 9 to District 8
# Total number of flips: 296
# Flipping 34017035101 from District 9 to District 8
# Total number of flips: 297
# Flipping 34013070E03 from District 10 to District 8
# Total number of flips: 297
# Flipping 34013070C44 from District 10 to District 8
# Total number of flips: 298
# Flipping 34017030A31 from District 10 to District 8
# Total number of flips: 299
# Flipping 34003090001 from District 9 to District 8
# Total number of flips: 300
# Flipping 34017035402 from District 9 to District 8
# Total number of flips: 301
# Flipping 34013070E03 from District 10 to District 8
# Total number of flips: 301
# Flipping 34017030F02 from District 10 to District 8
# Total number of flips: 302
# Flipping 34017045102 from District 9 to District 8
# Total number of flips: 303
# Flipping 34039075201 from District 10 to District 8
# Total number of flips: 304
# Flipping 34017030B04 from District 10 to District 8
# Total number of flips: 305
# Flipping 34017035204 from District 9 to District 8
# Total number of flips: 306
# Flipping 34013070E03 from District 10 to District 8
# Total number of flips: 306
# Flipping 34013070S49 from District 10 to District 8
# Total number of flips: 307
# Flipping 34013070W10 from District 10 to District 8
# Total number of flips: 308
# Flipping 34017030A08 from District 10 to District 8
# Total number of flips: 309
# Flipping 34013070C38 from District 10 to District 8
# Total number of flips: 310
# Flipping 34013070W09 from District 10 to District 8
# Total number of flips: 311
# Flipping 34017045201 from District 9 to District 8
# Total number of flips: 312
# Flipping 34017035107 from District 9 to District 8
# Total number of flips: 312
# Flipping 34017035205 from District 9 to District 8
# Total number of flips: 313
# Flipping 34017035204 from District 9 to District 8
# Total number of flips: 314
# Flipping 34003160004 from District 9 to District 8
# Total number of flips: 315
# Flipping 34039075201 from District 10 to District 8
# Total number of flips: 316
# Flipping 34017035107 from District 9 to District 8
# Total number of flips: 317
# Flipping 34039045804 from District 10 to District 8
# Total number of flips: 318
# Flipping 34013070E03 from District 10 to District 8
# Total number of flips: 318
# Flipping 34039035402 from District 10 to District 8
# Total number of flips: 319
# Flipping 34017030C11 from District 10 to District 8
# Total number of flips: 320
# Flipping 34017030B02 from District 10 to District 8
# Total number of flips: 321
# Flipping 34013005102 from District 11 to District 8
# Total number of flips: 322
# Flipping 34003090006 from District 9 to District 8
# Total number of flips: 323
# Flipping 34017030C11 from District 10 to District 8
# Total number of flips: 324
# Flipping 34013030510 from District 10 to District 8
# Total number of flips: 325
# Flipping 34017030C13 from District 10 to District 8
# Total number of flips: 325
# Flipping 34013070C01 from District 10 to District 8
# Total number of flips: 326
# Flipping 34013070E03 from District 10 to District 8
# Total number of flips: 326
# Flipping 34017030B04 from District 10 to District 8
# Total number of flips: 327
# Flipping 34017045102 from District 9 to District 8
# Total number of flips: 328
# Flipping 34017030F14 from District 10 to District 8
# Total number of flips: 329
# Flipping 34017035101 from District 9 to District 8
# Total number of flips: 330
# Flipping 34017030F14 from District 10 to District 8
# Total number of flips: 331
# Flipping 34003090006 from District 9 to District 8
# Total number of flips: 332
# Flipping 34017035204 from District 9 to District 8
# Total number of flips: 333
# Flipping 34013030510 from District 10 to District 8
# Total number of flips: 334
# Flipping 34013005105 from District 11 to District 8
# Total number of flips: 335
# Flipping 34017045205 from District 9 to District 8
# Total number of flips: 336
# Flipping 34039095017 from District 10 to District 8
# Total number of flips: 337
# Processing District 9
# 262
# Flipping 34013070N25 from District 8 to District 9
# Total number of flips: 337
# Flipping 34013005401 from District 11 to District 9
# Total number of flips: 338
# Flipping 34031080001 from District 11 to District 9
# Total number of flips: 339
# Flipping 34003085010 from District 5 to District 9
# Total number of flips: 340
# Flipping 34003115103 from District 5 to District 9
# Total number of flips: 340
# Flipping 34031070105 from District 11 to District 9
# Total number of flips: 341
# Flipping 34031070307 from District 11 to District 9
# Total number of flips: 342
# Flipping 34003230001 from District 5 to District 9
# Total number of flips: 343
# Flipping 34017040401 from District 8 to District 9
# Total number of flips: 344
# Flipping 34003095004 from District 5 to District 9
# Total number of flips: 344
# Flipping 34003165005 from District 5 to District 9
# Total number of flips: 344
# Flipping 34003095003 from District 5 to District 9
# Total number of flips: 345
# Flipping 34003115205 from District 5 to District 9
# Total number of flips: 346
# Flipping 34031025009 from District 11 to District 9
# Total number of flips: 347
# Flipping 34013010209 from District 11 to District 9
# Total number of flips: 348
# Flipping 34031080005 from District 11 to District 9
# Total number of flips: 349
# Flipping 34017035401 from District 8 to District 9
# Total number of flips: 349
# Flipping 34003115103 from District 5 to District 9
# Total number of flips: 349
# Flipping 34017035203 from District 8 to District 9
# Total number of flips: 350
# Flipping 34003250001 from District 5 to District 9
# Total number of flips: 351
# Flipping 34013005303 from District 11 to District 9
# Total number of flips: 352
# Flipping 34017035203 from District 8 to District 9
# Total number of flips: 353
# Flipping 34003085001 from District 5 to District 9
# Total number of flips: 354
# Flipping 34013070N10 from District 8 to District 9
# Total number of flips: 355
# Flipping 34003350004 from District 5 to District 9
# Total number of flips: 355
# Flipping 34017040401 from District 8 to District 9
# Total number of flips: 356
# Flipping 34017040506 from District 8 to District 9
# Total number of flips: 356
# Flipping 34013070N20 from District 8 to District 9
# Total number of flips: 357
# Flipping 34003110004 from District 5 to District 9
# Total number of flips: 358
# Flipping 34003085010 from District 5 to District 9
# Total number of flips: 359
# Flipping 34031065005 from District 5 to District 9
# Total number of flips: 360
# Flipping 34003095010 from District 5 to District 9
# Total number of flips: 360
# Flipping 34003095003 from District 5 to District 9
# Total number of flips: 361
# Flipping 34003085001 from District 5 to District 9
# Total number of flips: 362
# Flipping 34013010211 from District 11 to District 9
# Total number of flips: 363
# Flipping 34017035108 from District 8 to District 9
# Total number of flips: 364
# Flipping 34003085023 from District 5 to District 9
# Total number of flips: 365
# Flipping 34031025009 from District 11 to District 9
# Total number of flips: 366
# Flipping 34013080306 from District 11 to District 9
# Total number of flips: 367
# Flipping 34013005401 from District 11 to District 9
# Total number of flips: 368
# Flipping 34003095002 from District 5 to District 9
# Total number of flips: 368
# Flipping 34013080306 from District 11 to District 9
# Total number of flips: 369
# Flipping 34017020403 from District 8 to District 9
# Total number of flips: 370
# Flipping 34003165007 from District 5 to District 9
# Total number of flips: 370
# Flipping 34031060005 from District 11 to District 9
# Total number of flips: 371
# Flipping 34017035405 from District 8 to District 9
# Total number of flips: 371
# Flipping 34031070406 from District 11 to District 9
# Total number of flips: 372
# Flipping 34003115503 from District 5 to District 9
# Total number of flips: 373
# Flipping 34003250001 from District 5 to District 9
# Total number of flips: 374
# Flipping 34031070309 from District 11 to District 9
# Total number of flips: 375
# Processing District 10
# 345
# Flipping 34013055014 from District 11 to District 10
# Total number of flips: 376
# Flipping 34013095006 from District 11 to District 10
# Total number of flips: 377
# Flipping 34013065202 from District 11 to District 10
# Total number of flips: 378
# Flipping 34013055005 from District 11 to District 10
# Total number of flips: 379
# Flipping 34013010306 from District 11 to District 10
# Total number of flips: 380
# Flipping 34013025009 from District 11 to District 10
# Total number of flips: 381
# Flipping 34039100202 from District 7 to District 10
# Total number of flips: 382
# Flipping 34013040002 from District 11 to District 10
# Total number of flips: 383
# Flipping 34013075001 from District 11 to District 10
# Total number of flips: 384
# Flipping 34013070E02 from District 8 to District 10
# Total number of flips: 385
# Flipping 34013065308 from District 11 to District 10
# Total number of flips: 386
# Flipping 34039100206 from District 7 to District 10
# Total number of flips: 387
# Flipping 34013055005 from District 11 to District 10
# Total number of flips: 388
# Flipping 34017005310 from District 8 to District 10
# Total number of flips: 389
# Flipping 34013040007 from District 11 to District 10
# Total number of flips: 390
# Flipping 34013095012 from District 11 to District 10
# Total number of flips: 391
# Flipping 34013105002 from District 11 to District 10
# Total number of flips: 392
# Flipping 34039020406 from District 8 to District 10
# Total number of flips: 393
# Flipping 34013055005 from District 11 to District 10
# Total number of flips: 394
# Flipping 34013105006 from District 11 to District 10
# Total number of flips: 395
# Flipping 34013025009 from District 11 to District 10
# Total number of flips: 396
# Flipping 34013055010 from District 11 to District 10
# Total number of flips: 397
# Flipping 34013025009 from District 11 to District 10
# Total number of flips: 398
# Flipping 34039045103 from District 7 to District 10
# Total number of flips: 399
# Flipping 34013010309 from District 11 to District 10
# Total number of flips: 400
# Flipping 34017035206 from District 8 to District 10
# Total number of flips: 400
# Flipping 34017005319 from District 8 to District 10
# Total number of flips: 401
# Flipping 34017030F31 from District 8 to District 10
# Total number of flips: 401
# Flipping 34017030F28 from District 8 to District 10
# Total number of flips: 401
# Flipping 34013070N27 from District 8 to District 10
# Total number of flips: 402
# Flipping 34013065305 from District 11 to District 10
# Total number of flips: 403
# Flipping 34017030A09 from District 8 to District 10
# Total number of flips: 403
# Flipping 34039020501 from District 8 to District 10
# Total number of flips: 404
# Flipping 34013055001 from District 11 to District 10
# Total number of flips: 405
# Flipping 34017030E11 from District 8 to District 10
# Total number of flips: 406
# Flipping 34013095006 from District 11 to District 10
# Total number of flips: 407
# Flipping 34017030A34 from District 8 to District 10
# Total number of flips: 407
# Flipping 34013065303 from District 11 to District 10
# Total number of flips: 408
# Flipping 34039045303 from District 7 to District 10
# Total number of flips: 409
# Flipping 34013050017 from District 11 to District 10
# Total number of flips: 410
# Flipping 34039065204 from District 7 to District 10
# Total number of flips: 411
# Flipping 34039045301 from District 7 to District 10
# Total number of flips: 412
# Flipping 34013065401 from District 11 to District 10
# Total number of flips: 413
# Flipping 34013055014 from District 11 to District 10
# Total number of flips: 414
# Flipping 34017030F01 from District 8 to District 10
# Total number of flips: 414
# Flipping 34013095012 from District 11 to District 10
# Total number of flips: 415
# Flipping 34013010304 from District 11 to District 10
# Total number of flips: 416
# Flipping 34013040001 from District 11 to District 10
# Total number of flips: 417
# Flipping 34013070W43 from District 8 to District 10
# Total number of flips: 418
# Flipping 34039002048 from District 8 to District 10
# Total number of flips: 418
# Processing District 11
# 352
# Flipping 34035010001 from District 7 to District 11
# Total number of flips: 419
# Flipping 34031010113 from District 9 to District 11
# Total number of flips: 420
# Flipping 34035010003 from District 7 to District 11
# Total number of flips: 421
# Flipping 34013110413 from District 10 to District 11
# Total number of flips: 422
# Flipping 34013065306 from District 10 to District 11
# Total number of flips: 423
# Flipping 34039009541 from District 10 to District 11
# Total number of flips: 424
# Flipping 34031010120 from District 9 to District 11
# Total number of flips: 425
# Flipping 34031070601 from District 9 to District 11
# Total number of flips: 426
# Flipping 34027100002 from District 7 to District 11
# Total number of flips: 427
# Flipping 34031045003 from District 9 to District 11
# Total number of flips: 428
# Flipping 34013070N10 from District 8 to District 11
# Total number of flips: 429
# Flipping 34013027S05 from District 10 to District 11
# Total number of flips: 430
# Flipping 34031040204 from District 9 to District 11
# Total number of flips: 430
# Flipping 34039095005 from District 10 to District 11
# Total number of flips: 431
# Flipping 34031040207 from District 9 to District 11
# Total number of flips: 431
# Flipping 34003160015 from District 9 to District 11
# Total number of flips: 432
# Flipping 34039090102 from District 7 to District 11
# Total number of flips: 432
# Flipping 34013070N04 from District 8 to District 11
# Total number of flips: 433
# Flipping 34003160010 from District 9 to District 11
# Total number of flips: 434
# Flipping 34031040208 from District 9 to District 11
# Total number of flips: 435
# Flipping 34013030103 from District 10 to District 11
# Total number of flips: 436
# Flipping 34013110101 from District 10 to District 11
# Total number of flips: 437
# Flipping 34039090105 from District 7 to District 11
# Total number of flips: 438
# Flipping 34031010206 from District 9 to District 11
# Total number of flips: 438
# Flipping 34013110108 from District 10 to District 11
# Total number of flips: 438
# Flipping 34013070W35 from District 10 to District 11
# Total number of flips: 438
# Flipping 34013110402 from District 10 to District 11
# Total number of flips: 439
# Flipping 34039095005 from District 10 to District 11
# Total number of flips: 440
# Flipping 34039005002 from District 7 to District 11
# Total number of flips: 440
# Flipping 34031005001 from District 5 to District 11
# Total number of flips: 440
# Flipping 34013015007 from District 10 to District 11
# Total number of flips: 440
# Flipping 34013110108 from District 10 to District 11
# Total number of flips: 440
# Flipping 34003160015 from District 9 to District 11
# Total number of flips: 441
# Flipping 34031040204 from District 9 to District 11
# Total number of flips: 441
# Flipping 34027195001 from District 7 to District 11
# Total number of flips: 442
# Flipping 34031010106 from District 9 to District 11
# Total number of flips: 443
# Flipping 34037060004 from District 7 to District 11
# Total number of flips: 444
# Flipping 34013070N26 from District 8 to District 11
# Total number of flips: 445
# Flipping 34037090001 from District 7 to District 11
# Total number of flips: 445
# Flipping 34013070N06 from District 8 to District 11
# Total number of flips: 445
# Flipping 34013070N07 from District 8 to District 11
# Total number of flips: 446
# Flipping 34031040208 from District 9 to District 11
# Total number of flips: 447
# Flipping 34013100004 from District 10 to District 11
# Total number of flips: 448
# Flipping 34031075001 from District 5 to District 11
# Total number of flips: 449
# Flipping 34031070607 from District 9 to District 11
# Total number of flips: 450
# Flipping 34039095039 from District 10 to District 11
# Total number of flips: 451
# Flipping 34013110503 from District 10 to District 11
# Total number of flips: 452
# Flipping 34027195001 from District 7 to District 11
# Total number of flips: 453
# Flipping 34031005002 from District 5 to District 11
# Total number of flips: 454
# Flipping 34031005001 from District 5 to District 11
# Total number of flips: 454
# Processing District 12
# 287
# Flipping 34023070606 from District 6 to District 12
# Total number of flips: 455
# Flipping 34021015012 from District 3 to District 12
# Total number of flips: 455
# Flipping 34023085310 from District 6 to District 12
# Total number of flips: 456
# Flipping 34025140018 from District 3 to District 12
# Total number of flips: 457
# Flipping 34025130001 from District 3 to District 12
# Total number of flips: 458
# Flipping 34023095002 from District 6 to District 12
# Total number of flips: 459
# Flipping 34021035007 from District 3 to District 12
# Total number of flips: 460
# Flipping 34035045003 from District 7 to District 12
# Total number of flips: 461
# Flipping 34035105005 from District 7 to District 12
# Total number of flips: 461
# Flipping 34035050010 from District 7 to District 12
# Total number of flips: 462
# Flipping 34025160003 from District 3 to District 12
# Total number of flips: 463
# Flipping 34021060003 from District 3 to District 12
# Total number of flips: 464
# Flipping 34023070605 from District 6 to District 12
# Total number of flips: 465
# Flipping 34021035021 from District 3 to District 12
# Total number of flips: 466
# Flipping 34023070404 from District 6 to District 12
# Total number of flips: 467
# Flipping 34023085301 from District 6 to District 12
# Total number of flips: 467
# Flipping 34021060008 from District 3 to District 12
# Total number of flips: 468
# Flipping 34023077408 from District 6 to District 12
# Total number of flips: 468
# Flipping 34021035021 from District 3 to District 12
# Total number of flips: 469
# Flipping 34021035021 from District 3 to District 12
# Total number of flips: 470
# Flipping 34023077203 from District 6 to District 12
# Total number of flips: 471
# Flipping 34023085305 from District 6 to District 12
# Total number of flips: 471
# Flipping 34025140018 from District 3 to District 12
# Total number of flips: 472
# Flipping 34023070502 from District 6 to District 12
# Total number of flips: 473
# Flipping 34021035016 from District 3 to District 12
# Total number of flips: 473
# Flipping 34019040003 from District 7 to District 12
# Total number of flips: 474
# Flipping 34023085301 from District 6 to District 12
# Total number of flips: 474
# Flipping 34021005011 from District 3 to District 12
# Total number of flips: 475
# Flipping 34035045001 from District 7 to District 12
# Total number of flips: 475
# Flipping 34035045003 from District 7 to District 12
# Total number of flips: 476
# Flipping 34023110006 from District 6 to District 12
# Total number of flips: 477
# Flipping 34021005004 from District 3 to District 12
# Total number of flips: 478
# Flipping 34021005004 from District 3 to District 12
# Total number of flips: 479
# Flipping 34023085309 from District 6 to District 12
# Total number of flips: 480
# Flipping 34021035003 from District 3 to District 12
# Total number of flips: 481
# Flipping 34035030001 from District 7 to District 12
# Total number of flips: 481
# Flipping 34021035006 from District 3 to District 12
# Total number of flips: 482
# Flipping 34035045001 from District 7 to District 12
# Total number of flips: 482
# Flipping 34021035005 from District 3 to District 12
# Total number of flips: 482
# Flipping 34021035017 from District 3 to District 12
# Total number of flips: 482
# Flipping 34023110013 from District 6 to District 12
# Total number of flips: 482
# Flipping 34039080002 from District 7 to District 12
# Total number of flips: 483
# Flipping 34025003013 from District 6 to District 12
# Total number of flips: 484
# Flipping 34035105005 from District 7 to District 12
# Total number of flips: 484
# Flipping 34035030001 from District 7 to District 12
# Total number of flips: 484
# Flipping 34021035016 from District 3 to District 12
# Total number of flips: 484
# Flipping 34035045003 from District 7 to District 12
# Total number of flips: 485
# Flipping 34023085101 from District 6 to District 12
# Total number of flips: 486
# Flipping 34021035004 from District 3 to District 12
# Total number of flips: 486
# Flipping 34025140024 from District 3 to District 12
# Total number of flips: 487
# Processing District 1
# 117
# Flipping 34001065002 from District 2 to District 1
# Total number of flips: 488
# Flipping 34015035006 from District 2 to District 1
# Total number of flips: 489
# Flipping 34005040005 from District 3 to District 1
# Total number of flips: 490
# Flipping 34005125006 from District 3 to District 1
# Total number of flips: 491
# Flipping 34015020001 from District 2 to District 1
# Total number of flips: 492
# Flipping 34005165003 from District 3 to District 1
# Total number of flips: 493
# Flipping 34015020001 from District 2 to District 1
# Total number of flips: 494
# Flipping 34001065002 from District 2 to District 1
# Total number of flips: 495
# ...
# Total number of flips: 515
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 515
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 515
# Flipping 34015040007 from District 2 to District 1
# Total number of flips: 516
# Flipping 34005160002 from District 3 to District 1
# Total number of flips: 516
# Flipping 34005040006 from District 3 to District 1
# Total number of flips: 517
# Flipping 34015005006 from District 2 to District 1
# Total number of flips: 518
# Flipping 34005115001 from District 3 to District 1
# Total number of flips: 519
# Flipping 34015015006 from District 2 to District 1
# Total number of flips: 519
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 519
# Flipping 34001065006 from District 2 to District 1
# Total number of flips: 520
# Flipping 34005065001 from District 3 to District 1
# Total number of flips: 521
# Flipping 34015020002 from District 2 to District 1
# Total number of flips: 522
# Flipping 34005065001 from District 3 to District 1
# Total number of flips: 523
# Flipping 34005040005 from District 3 to District 1
# Total number of flips: 524
# Flipping 34005065020 from District 3 to District 1
# Total number of flips: 524
# Processing District 2
# 129
# Flipping 34029025205 from District 4 to District 2
# Total number of flips: 525
# Flipping 34015070005 from District 1 to District 2
# Total number of flips: 526
# Flipping 34029060004 from District 4 to District 2
# Total number of flips: 527
# Flipping 34015055326 from District 1 to District 2
# Total number of flips: 527
# Flipping 34015050001 from District 1 to District 2
# Total number of flips: 527
# Flipping 34029025320 from District 4 to District 2
# Total number of flips: 528
# Flipping 34029025137 from District 4 to District 2
# Total number of flips: 529
# Flipping 34015015004 from District 1 to District 2
# Total number of flips: 530
# Flipping 34015070002 from District 1 to District 2
# Total number of flips: 531
# Flipping 34005005001 from District 3 to District 2
# Total number of flips: 532
# Flipping 34005195001 from District 3 to District 2
# Total number of flips: 533
# Flipping 34015055122 from District 1 to District 2
# Total number of flips: 534
# Flipping 34029060010 from District 4 to District 2
# Total number of flips: 534
# Flipping 34029060004 from District 4 to District 2
# Total number of flips: 535
# Flipping 34015055404 from District 1 to District 2
# Total number of flips: 536
# Flipping 34029060007 from District 4 to District 2
# Total number of flips: 536
# Flipping 34015050001 from District 1 to District 2
# Total number of flips: 536
# Flipping 34029060004 from District 4 to District 2
# Total number of flips: 537
# Flipping 34015030005 from District 1 to District 2
# Total number of flips: 538
# Flipping 34029060013 from District 4 to District 2
# Total number of flips: 539
# Flipping 34015055408 from District 1 to District 2
# Total number of flips: 540
# Flipping 34015015003 from District 1 to District 2
# Total number of flips: 541
# Flipping 34015015002 from District 1 to District 2
# Total number of flips: 541
# Flipping 34015030005 from District 1 to District 2
# Total number of flips: 542
# Flipping 34029130001 from District 4 to District 2
# Total number of flips: 543
# Flipping 34015055326 from District 1 to District 2
# Total number of flips: 544
# Flipping 34015030008 from District 1 to District 2
# Total number of flips: 544
# Flipping 34015030013 from District 1 to District 2
# Total number of flips: 544
# Flipping 34029060010 from District 4 to District 2
# Total number of flips: 544
# Flipping 34015030002 from District 1 to District 2
# Total number of flips: 545
# Flipping 34029105001 from District 4 to District 2
# Total number of flips: 545
# Flipping 34015015002 from District 1 to District 2
# Total number of flips: 545
# Flipping 34015030005 from District 1 to District 2
# Total number of flips: 546
# Flipping 34029060013 from District 4 to District 2
# Total number of flips: 547
# Flipping 34029060017 from District 4 to District 2
# Total number of flips: 548
# Flipping 34005185001 from District 3 to District 2
# Total number of flips: 549
# Flipping 34005195001 from District 3 to District 2
# Total number of flips: 550
# Flipping 34015030005 from District 1 to District 2
# Total number of flips: 551
# Flipping 34015015004 from District 1 to District 2
# Total number of flips: 552
# Flipping 34015030013 from District 1 to District 2
# Total number of flips: 552
# Flipping 34005005001 from District 3 to District 2
# Total number of flips: 553
# Flipping 34005165002 from District 3 to District 2
# Total number of flips: 554
# Flipping 34029025107 from District 4 to District 2
# Total number of flips: 555
# Flipping 34015070005 from District 1 to District 2
# Total number of flips: 556
# Flipping 34007180101 from District 1 to District 2
# Total number of flips: 556
# Flipping 34029025137 from District 4 to District 2
# Total number of flips: 557
# Flipping 34005185001 from District 3 to District 2
# Total number of flips: 558
# Flipping 34029060010 from District 4 to District 2
# Total number of flips: 558
# Flipping 34029060012 from District 4 to District 2
# Total number of flips: 559
# Flipping 34029060013 from District 4 to District 2
# Total number of flips: 560
# Processing District 3
# 264
# Flipping 34029115002 from District 4 to District 3
# Total number of flips: 560
# Flipping 34021065012 from District 12 to District 3
# Total number of flips: 561
# Flipping 34021055E06 from District 12 to District 3
# Total number of flips: 561
# Flipping 34005140003 from District 1 to District 3
# Total number of flips: 561
# Flipping 34021055N05 from District 12 to District 3
# Total number of flips: 562
# Flipping 34023065308 from District 12 to District 3
# Total number of flips: 562
# Flipping 34001042203 from District 2 to District 3
# Total number of flips: 562
# Flipping 34025155039 from District 4 to District 3
# Total number of flips: 562
# Flipping 34021055S04 from District 12 to District 3
# Total number of flips: 563
# Flipping 34025155039 from District 4 to District 3
# Total number of flips: 563
# Flipping 34021065016 from District 12 to District 3
# Total number of flips: 564
# Flipping 34021065016 from District 12 to District 3
# Total number of flips: 565
# Flipping 34001085301 from District 2 to District 3
# Total number of flips: 565
# Flipping 34025082017 from District 6 to District 3
# Total number of flips: 566
# Flipping 34023077510 from District 12 to District 3
# Total number of flips: 567
# Flipping 34021010014 from District 12 to District 3
# Total number of flips: 568
# Flipping 34029080007 from District 2 to District 3
# Total number of flips: 568
# Flipping 34021065013 from District 12 to District 3
# Total number of flips: 569
# Flipping 34005140002 from District 1 to District 3
# Total number of flips: 570
# Flipping 34023077207 from District 12 to District 3
# Total number of flips: 570
# Flipping 34021030001 from District 12 to District 3
# Total number of flips: 571
# Flipping 34023077208 from District 12 to District 3
# Total number of flips: 572
# Flipping 34025003009 from District 6 to District 3
# Total number of flips: 573
# Flipping 34021065012 from District 12 to District 3
# Total number of flips: 574
# Flipping 34029080002 from District 2 to District 3
# Total number of flips: 574
# Flipping 34021055S08 from District 12 to District 3
# Total number of flips: 575
# Flipping 34025155044 from District 4 to District 3
# Total number of flips: 576
# Flipping 34005100008 from District 1 to District 3
# Total number of flips: 576
# Flipping 34025155019 from District 4 to District 3
# Total number of flips: 577
# Flipping 34029115003 from District 4 to District 3
# Total number of flips: 578
# Flipping 34025155019 from District 4 to District 3
# Total number of flips: 579
# Flipping 34023077202 from District 12 to District 3
# Total number of flips: 579
# Flipping 34023065204 from District 12 to District 3
# Total number of flips: 580
# Flipping 34021055E06 from District 12 to District 3
# Total number of flips: 580
# Flipping 34005100006 from District 1 to District 3
# Total number of flips: 580
# Flipping 34005140001 from District 1 to District 3
# Total number of flips: 581
# Flipping 34021030001 from District 12 to District 3
# Total number of flips: 582
# Flipping 34025155038 from District 4 to District 3
# Total number of flips: 583
# Flipping 34007043045 from District 1 to District 3
# Total number of flips: 584
# Flipping 34025080011 from District 4 to District 3
# Total number of flips: 584
# Flipping 34007043045 from District 1 to District 3
# Total number of flips: 585
# Flipping 34021050001 from District 12 to District 3
# Total number of flips: 586
# Flipping 34025095028 from District 4 to District 3
# Total number of flips: 586
# Flipping 34025095020 from District 4 to District 3
# Total number of flips: 587
# Flipping 34025003011 from District 6 to District 3
# Total number of flips: 588
# Flipping 34025082002 from District 6 to District 3
# Total number of flips: 589
# Flipping 34029150005 from District 2 to District 3
# Total number of flips: 589
# Flipping 34021050001 from District 12 to District 3
# Total number of flips: 590
# Flipping 34029150005 from District 2 to District 3
# Total number of flips: 590
# Flipping 34001055008 from District 2 to District 3
# Total number of flips: 590
# Processing District 4
# 223
# Flipping 34029025116 from District 2 to District 4
# Total number of flips: 591
# Flipping 34029060001 from District 2 to District 4
# Total number of flips: 591
# Flipping 34025160005 from District 3 to District 4
# Total number of flips: 592
# Flipping 34025200001 from District 6 to District 4
# Total number of flips: 592
# Flipping 34025265001 from District 6 to District 4
# Total number of flips: 593
# Flipping 34025210002 from District 6 to District 4
# Total number of flips: 594
# Flipping 34029102001 from District 2 to District 4
# Total number of flips: 595
# Flipping 34025265002 from District 6 to District 4
# Total number of flips: 596
# Flipping 34029102002 from District 2 to District 4
# Total number of flips: 596
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 596
# Flipping 34025050001 from District 6 to District 4
# Total number of flips: 597
# Flipping 34025210002 from District 6 to District 4
# Total number of flips: 598
# Flipping 34025200009 from District 6 to District 4
# Total number of flips: 598
# Flipping 34029102001 from District 2 to District 4
# Total number of flips: 599
# Flipping 34025080024 from District 3 to District 4
# Total number of flips: 600
# Flipping 34025090005 from District 3 to District 4
# Total number of flips: 601
# Flipping 34025050001 from District 6 to District 4
# Total number of flips: 602
# Flipping 34025170016 from District 6 to District 4
# Total number of flips: 603
# Flipping 34025200009 from District 6 to District 4
# Total number of flips: 603
# Flipping 34025140003 from District 3 to District 4
# Total number of flips: 603
# Flipping 34025170011 from District 6 to District 4
# Total number of flips: 604
# Flipping 34025090010 from District 3 to District 4
# Total number of flips: 604
# Flipping 34025080022 from District 3 to District 4
# Total number of flips: 605
# Flipping 34025160005 from District 3 to District 4
# Total number of flips: 606
# Flipping 34025265001 from District 6 to District 4
# Total number of flips: 607
# Flipping 34025255001 from District 3 to District 4
# Total number of flips: 608
# Flipping 34025080024 from District 3 to District 4
# Total number of flips: 609
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 609
# Flipping 34025155027 from District 6 to District 4
# Total number of flips: 610
# Flipping 34029102001 from District 2 to District 4
# Total number of flips: 611
# Flipping 34025155027 from District 6 to District 4
# Total number of flips: 612
# Flipping 34025172002 from District 6 to District 4
# Total number of flips: 613
# Flipping 34025265002 from District 6 to District 4
# Total number of flips: 614
# Flipping 34029102001 from District 2 to District 4
# Total number of flips: 615
# Flipping 34025090004 from District 3 to District 4
# Total number of flips: 616
# Flipping 34029ZZZZZZ from District 2 to District 4
# Total number of flips: 616
# Flipping 34025080018 from District 3 to District 4
# Total number of flips: 617
# Flipping 34029025134 from District 2 to District 4
# Total number of flips: 618
# Flipping 34029025139 from District 2 to District 4
# Total number of flips: 619
# Flipping 34025140025 from District 3 to District 4
# Total number of flips: 620
# Flipping 34025115001 from District 6 to District 4
# Total number of flips: 621
# Flipping 34025200006 from District 6 to District 4
# Total number of flips: 622
# Flipping 34029025236 from District 2 to District 4
# Total number of flips: 622
# Flipping 34025080018 from District 3 to District 4
# Total number of flips: 623
# Flipping 34025100001 from District 6 to District 4
# Total number of flips: 624
# Flipping 34025080024 from District 3 to District 4
# Total number of flips: 625
# Flipping 34025155036 from District 6 to District 4
# Total number of flips: 626
# Flipping 34025190004 from District 6 to District 4
# Total number of flips: 627
# Flipping 34025ZZZZZZ from District 6 to District 4
# Total number of flips: 627
# Flipping 34025200006 from District 6 to District 4
# Total number of flips: 628
# Processing District 5
# 171
# Flipping 34003150004 from District 9 to District 5
# Total number of flips: 629
# Flipping 34003067005 from District 9 to District 5
# Total number of flips: 629
# Flipping 34003245003 from District 9 to District 5
# Total number of flips: 630
# Flipping 34037020003 from District 7 to District 5
# Total number of flips: 631
# Flipping 34031020202 from District 9 to District 5
# Total number of flips: 632
# Flipping 34031045002 from District 9 to District 5
# Total number of flips: 633
# Flipping 34031040309 from District 9 to District 5
# Total number of flips: 634
# Flipping 34003100001 from District 9 to District 5
# Total number of flips: 635
# Flipping 34031020203 from District 9 to District 5
# Total number of flips: 636
# Flipping 34003067005 from District 9 to District 5
# Total number of flips: 636
# Flipping 34003295001 from District 9 to District 5
# Total number of flips: 637
# Flipping 34037090012 from District 7 to District 5
# Total number of flips: 638
# Flipping 34031040305 from District 9 to District 5
# Total number of flips: 639
# Flipping 34003155012 from District 9 to District 5
# Total number of flips: 640
# Flipping 34037080001 from District 7 to District 5
# Total number of flips: 640
# Flipping 34027075003 from District 11 to District 5
# Total number of flips: 641
# Flipping 34003150006 from District 9 to District 5
# Total number of flips: 641
# Flipping 34031020202 from District 9 to District 5
# Total number of flips: 642
# Flipping 34031045002 from District 9 to District 5
# Total number of flips: 643
# Flipping 34027070013 from District 11 to District 5
# Total number of flips: 644
# Flipping 34003030011 from District 9 to District 5
# Total number of flips: 645
# Flipping 34037090003 from District 7 to District 5
# Total number of flips: 646
# Flipping 34003285010 from District 9 to District 5
# Total number of flips: 647
# Flipping 34003270002 from District 9 to District 5
# Total number of flips: 647
# Flipping 34037090003 from District 7 to District 5
# Total number of flips: 648
# Flipping 34037100002 from District 7 to District 5
# Total number of flips: 649
# Flipping 34003100004 from District 9 to District 5
# Total number of flips: 650
# Flipping 34031040309 from District 9 to District 5
# Total number of flips: 651
# Processing District 6
# 279
# Flipping 34025140026 from District 3 to District 6
# Total number of flips: 652
# Processing District 7
# 312
# Flipping 34027070001 from District 11 to District 7
# Total number of flips: 653
# Processing District 8
# 233
# Flipping 34017035402 from District 9 to District 8
# Total number of flips: 654
# Processing District 9
# 262
# Flipping 34017035401 from District 8 to District 9
# Total number of flips: 654
# Processing District 10
# 345
# Flipping 34039045101 from District 7 to District 10
# Total number of flips: 655
# Processing District 11
# 352
# Flipping 34013035001 from District 10 to District 11
# Total number of flips: 656
# Processing District 12
# 287
# Flipping 34025130002 from District 3 to District 12
# Total number of flips: 657
# Total number of flips: 657

# %%
fair_assignment = pd.read_csv('/content/New Jersey Data/precinct-assignments-congress-nj.csv')


print("New Jersey Fair Assignment Contiguity Check")
for i in range(1,13):
    print("District "+str(i)+" "+str(isDistrictContiguous(i, fair_assignment, nj_contiguity)))
# Out:
# New Jersey Fair Assignment Contiguity Check
# District 1 True
# District 2 True
# District 3 True
# District 4 True
# District 5 True
# District 6 True
# District 7 True
# District 8 True
# District 9 True
# District 10 True
# District 11 True
# District 12 True
